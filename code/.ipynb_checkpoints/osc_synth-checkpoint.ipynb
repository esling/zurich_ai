# %%
from pythonosc import osc_server
from pythonosc import dispatcher

# %%
# ?dispatcher.Dispatcher
# Out:
# Init signature: dispatcher.Dispatcher() -> None
# Docstring:
# Maps Handlers to OSC addresses and dispatches messages to the handler on matched addresses
#
# Maps OSC addresses to handler functions and invokes the correct handler when a message comes in.
# File:           ~/Library/Python/3.9/lib/python/site-packages/pythonosc/dispatcher.py
# Type:           type
# Subclasses:

# %%
ip = "localhost"
ip = "127.0.0.1"
port = 1236
# Function to react to an incoming /synth/frequency message
def synth_freq_fun(address, freq):
    print(f"Received frequency : %f", freq)
# Create a dispatcher
dispatch = dispatcher.Dispatcher()
# Mapping message to the function
dispatch.map("/synth/frequency", synth_freq_fun)
# Create the server
server = osc_server.ThreadingOSCUDPServer((ip, port), dispatch)
# Launch the server
server.serve_forever()
# Out:
# Received frequency : %f 440.0
# Received frequency : %f 440.0
# Received frequency : %f 440.0
# Received frequency : %f 440.0
# Received frequency : %f 440.0
# Received frequency : %f 67.0
# Received frequency : %f 71.0
# Received frequency : %f 74.0
# Received frequency : %f 77.0
# Received frequency : %f 78.0
# Received frequency : %f 79.0
# Received frequency : %f 80.0
# Received frequency : %f 81.0
# Received frequency : %f 82.0
# Received frequency : %f 83.0
# Received frequency : %f 84.0
# Received frequency : %f 85.0
# Received frequency : %f 86.0
# Received frequency : %f 87.0
# Received frequency : %f 88.0
# Received frequency : %f 89.0
# Received frequency : %f 90.0
# Received frequency : %f 91.0
# Received frequency : %f 92.0
# Received frequency : %f 93.0
# Received frequency : %f 94.0
# Received frequency : %f 93.0
# Received frequency : %f 92.0
# Received frequency : %f 89.0
# Received frequency : %f 85.0
# Received frequency : %f 83.0
# Received frequency : %f 81.0
# Received frequency : %f 79.0
# Received frequency : %f 77.0
# Received frequency : %f 75.0
# Received frequency : %f 72.0
# Received frequency : %f 69.0
# Received frequency : %f 68.0
# Received frequency : %f 63.0
# Received frequency : %f 61.0
# Received frequency : %f 58.0
# Received frequency : %f 56.0
# Received frequency : %f 55.0
# Received frequency : %f 54.0
# Received frequency : %f 53.0
# Received frequency : %f 52.0
# Received frequency : %f 51.0
# Received frequency : %f 50.0
# Received frequency : %f 49.0
# Received frequency : %f 52.0
# Received frequency : %f 57.0
# Received frequency : %f 62.0
# Received frequency : %f 66.0
# Received frequency : %f 69.0
# Received frequency : %f 70.0
# Received frequency : %f 72.0
# Received frequency : %f 74.0
# Received frequency : %f 78.0
# Received frequency : %f 81.0
# Received frequency : %f 83.0
# Received frequency : %f 84.0
# Received frequency : %f 83.0
# Received frequency : %f 82.0
# Received frequency : %f 80.0
# Received frequency : %f 79.0
# Received frequency : %f 77.0
# Received frequency : %f 73.0
# Received frequency : %f 68.0
# Received frequency : %f 62.0
# Received frequency : %f 56.0
# Received frequency : %f 52.0
# Received frequency : %f 49.0
# Received frequency : %f 48.0
# Received frequency : %f 50.0
# Received frequency : %f 55.0
# Received frequency : %f 60.0
# Received frequency : %f 65.0
# Received frequency : %f 69.0
# Received frequency : %f 72.0
# Received frequency : %f 74.0
# Received frequency : %f 75.0
# Received frequency : %f 76.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 13
#      11 server = osc_server.ThreadingOSCUDPServer((ip, port), dispatch)
#      12 # Launch the server
# ---> 13 server.serve_forever()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/socketserver.py:232, in BaseServer.serve_forever(self, poll_interval)
#     229 selector.register(self, selectors.EVENT_READ)
#     231 while not self.__shutdown_request:
# --> 232     ready = selector.select(poll_interval)
#     233     # bpo-35017: shutdown() called during select(), exit immediately.
#     234     if self.__shutdown_request:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %%
# ?dispatch.map
# /synth/frequency 440.0 ?
#server.serve_forever()

# %%
# Writing Python client
from pythonosc import udp_client
#?udp_client.SimpleUDPClient
ip = "127.0.0.1"
port = 8000
client = udp_client.SimpleUDPClient(ip, port)
client.send_message("/synth/frequency", 440.0)

# %%
# Out:
# Received frequency : %f 94.0
# Received frequency : %f 91.0
# Received frequency : %f 88.0
# Received frequency : %f 85.0
# Received frequency : %f 83.0
# Received frequency : %f 80.0
# Received frequency : %f 77.0
# Received frequency : %f 74.0
# Received frequency : %f 72.0
# Received frequency : %f 69.0
# Received frequency : %f 67.0
# Received frequency : %f 65.0
# Received frequency : %f 64.0
# Received frequency : %f 63.0
# Received frequency : %f 62.0
# Received frequency : %f 61.0
# Received frequency : %f 60.0
# Received frequency : %f 61.0
# Received frequency : %f 62.0
# Received frequency : %f 63.0
# Received frequency : %f 65.0
# Received frequency : %f 70.0
# Received frequency : %f 78.0
# Received frequency : %f 87.0
# Received frequency : %f 94.0
# Received frequency : %f 99.0
# Received frequency : %f 102.0
# Received frequency : %f 104.0
# Received frequency : %f 105.0
# Received frequency : %f 106.0
# Received frequency : %f 107.0
# Received frequency : %f 108.0
# Received frequency : %f 110.0
# Received frequency : %f 114.0
# Received frequency : %f 119.0
# Received frequency : %f 124.0
# Received frequency : %f 127.0
# Received frequency : %f 125.0
# Received frequency : %f 122.0
# Received frequency : %f 120.0
# Received frequency : %f 119.0
# Received frequency : %f 118.0
# Received frequency : %f 117.0
# Received frequency : %f 116.0
# Received frequency : %f 113.0
# Received frequency : %f 109.0
# Received frequency : %f 106.0
# Received frequency : %f 103.0
# Received frequency : %f 102.0
# Received frequency : %f 101.0
# Received frequency : %f 99.0
# Received frequency : %f 98.0
# Received frequency : %f 97.0
# Received frequency : %f 98.0
# Received frequency : %f 99.0
# Received frequency : %f 101.0
# Received frequency : %f 103.0
# Received frequency : %f 106.0
# Received frequency : %f 111.0
# Received frequency : %f 120.0
# Received frequency : %f 127.0
# Received frequency : %f 126.0
# Received frequency : %f 124.0
# Received frequency : %f 122.0
# Received frequency : %f 120.0
# Received frequency : %f 119.0
# Received frequency : %f 118.0
# Received frequency : %f 116.0
# Received frequency : %f 114.0
# Received frequency : %f 111.0
# Received frequency : %f 108.0
# Received frequency : %f 106.0
# Received frequency : %f 104.0
# Received frequency : %f 102.0
# Received frequency : %f 101.0
# Received frequency : %f 102.0
# Received frequency : %f 103.0
# Received frequency : %f 106.0
# Received frequency : %f 108.0
# Received frequency : %f 110.0
# Received frequency : %f 111.0
# Received frequency : %f 110.0
# Received frequency : %f 109.0
# Received frequency : %f 106.0
# Received frequency : %f 104.0
# Received frequency : %f 100.0
# Received frequency : %f 95.0
# Received frequency : %f 88.0
# Received frequency : %f 78.0
# Received frequency : %f 69.0
# Received frequency : %f 61.0
# Received frequency : %f 56.0
# Received frequency : %f 52.0
# Received frequency : %f 51.0
# Received frequency : %f 54.0
# Received frequency : %f 60.0
# Received frequency : %f 65.0
# Received frequency : %f 70.0
# Received frequency : %f 73.0
# Received frequency : %f 77.0
# Received frequency : %f 82.0
# Received frequency : %f 87.0
# Received frequency : %f 92.0
# Received frequency : %f 95.0
# Received frequency : %f 97.0
# Received frequency : %f 98.0
# Received frequency : %f 99.0
# Received frequency : %f 98.0
# Received frequency : %f 97.0
# Received frequency : %f 95.0
# Received frequency : %f 93.0
# Received frequency : %f 92.0
# Received frequency : %f 90.0
# Received frequency : %f 89.0
# Received frequency : %f 88.0
# Received frequency : %f 87.0
# Received frequency : %f 86.0
# Received frequency : %f 87.0
# Received frequency : %f 90.0
# Received frequency : %f 94.0
# Received frequency : %f 97.0
# Received frequency : %f 98.0
# Received frequency : %f 99.0
# Received frequency : %f 96.0
# Received frequency : %f 93.0
# Received frequency : %f 90.0
# Received frequency : %f 88.0
# Received frequency : %f 87.0
# Received frequency : %f 88.0
# Received frequency : %f 89.0
# Received frequency : %f 90.0
# Received frequency : %f 91.0
# Received frequency : %f 92.0
# Received frequency : %f 91.0
# Received frequency : %f 90.0
# Received frequency : %f 89.0
# Received frequency : %f 88.0
# Received frequency : %f 89.0
# Received frequency : %f 88.0
# Received frequency : %f 86.0
# Received frequency : %f 83.0
# Received frequency : %f 80.0
# Received frequency : %f 78.0
# Received frequency : %f 77.0
# Received frequency : %f 76.0
# Received frequency : %f 77.0
# Received frequency : %f 79.0
# Received frequency : %f 80.0
# Received frequency : %f 81.0
# Received frequency : %f 82.0
# Received frequency : %f 83.0
# Received frequency : %f 88.0
# Received frequency : %f 89.0
# Received frequency : %f 90.0
# Received frequency : %f 91.0
# Received frequency : %f 92.0
# Received frequency : %f 93.0
# Received frequency : %f 94.0
# Received frequency : %f 98.0
# Received frequency : %f 99.0
# Received frequency : %f 100.0
# Received frequency : %f 101.0
# Received frequency : %f 102.0
# Received frequency : %f 103.0
# Received frequency : %f 104.0
# Received frequency : %f 105.0
# Received frequency : %f 107.0
# Received frequency : %f 108.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 17
#      15 server = osc_server.ThreadingOSCUDPServer((ip, port_in), dispatch)
#      16 # Launch the server
# ---> 17 server.serve_forever()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/socketserver.py:232, in BaseServer.serve_forever(self, poll_interval)
#     229 selector.register(self, selectors.EVENT_READ)
#     231 while not self.__shutdown_request:
# --> 232     ready = selector.select(poll_interval)
#     233     # bpo-35017: shutdown() called during select(), exit immediately.
#     234     if self.__shutdown_request:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %%
class OSCServer():

    def __init__(self, in_port, out_port, ip="127.0.0.1", *args):
        self.ip = ip
        self.port_in = in_port
        self.port_out = out_port
        # Client object to use in functions
        self.client = udp_client.SimpleUDPClient(self.ip, self.port_out)
        # Create a dispatcher
        self.dispatch = dispatcher.Dispatcher()
        # Initialize all bindings
        self.init_bindings()
        # Create the server
        self.server = osc_server.BlockingOSCUDPServer((ip, self.port_in), self.dispatch)

    def init_bindings(self):
        # Mapping message to the function
        self.dispatch.map("/synth/frequency", self.synth_frequency)
        self.dispatch.map("/stop", self.stop_server)

    # Function to react to an incoming /synth/frequency message
    def synth_frequency(self, address, freq):
        print(f"Received frequency : {freq}")
        # Advanced complicated computing here
        new_freq = freq * 2
        # Send back the frequency
        self.client.send_message("/synth/frequency", new_freq)

    def start_server(self):
        # Launch the server
        self.server.serve_forever()

    def stop_server(self):
        self.client.send_message("/terminated", "bang")
        self.server.shutdown()
        self.server.socket.close()

# %%
server = OSCServer(1223, 1224)
server.start_server()
# Out:
# Received frequency : 77.0
# Received frequency : 78.0
# Received frequency : 79.0
# Received frequency : 80.0
# Received frequency : 82.0
# Received frequency : 83.0
# Received frequency : 84.0
# Received frequency : 85.0
# Received frequency : 86.0
# Received frequency : 92.0
# Received frequency : 93.0
# Received frequency : 94.0
# Received frequency : 95.0
# Received frequency : 96.0
# Received frequency : 98.0
# Received frequency : 99.0
# Received frequency : 100.0
# Received frequency : 101.0
# Received frequency : 102.0
# Received frequency : 103.0
# Received frequency : 102.0
# Received frequency : 101.0
# Received frequency : 100.0
# Received frequency : 99.0
# Received frequency : 98.0
# Received frequency : 97.0
# Received frequency : 96.0
# Received frequency : 94.0
# Received frequency : 93.0
# Received frequency : 92.0
# Received frequency : 91.0
# Received frequency : 90.0
# Received frequency : 89.0
# Received frequency : 88.0
# Received frequency : 87.0
# Received frequency : 86.0
# Received frequency : 85.0
# Received frequency : 84.0
# Received frequency : 83.0
# Received frequency : 82.0
# Received frequency : 81.0
# Received frequency : 80.0
# Received frequency : 79.0
# Received frequency : 78.0
# Received frequency : 77.0
# Received frequency : 73.0
# Received frequency : 70.0
# Received frequency : 69.0
# Received frequency : 68.0
# Received frequency : 67.0
# Received frequency : 66.0
# Received frequency : 65.0
# Received frequency : 64.0
# Received frequency : 63.0
# Received frequency : 62.0
# Received frequency : 61.0
# Received frequency : 60.0
# Received frequency : 59.0
# Received frequency : 58.0
# Received frequency : 57.0
# Received frequency : 56.0
# Received frequency : 55.0
# Received frequency : 54.0
# Received frequency : 53.0
# Received frequency : 52.0
# Received frequency : 56.0
# Received frequency : 57.0
# Received frequency : 58.0
# Received frequency : 59.0
# Received frequency : 60.0
# Received frequency : 61.0
# Received frequency : 62.0
# Received frequency : 63.0
# Received frequency : 64.0
# Received frequency : 66.0
# Received frequency : 68.0
# Received frequency : 69.0
# Received frequency : 70.0
# Received frequency : 71.0
# Received frequency : 72.0
# Received frequency : 71.0
# Received frequency : 70.0
# Received frequency : 71.0
# Received frequency : 72.0
# Received frequency : 71.0
# Received frequency : 70.0
# Received frequency : 69.0
# Received frequency : 68.0
# Received frequency : 67.0
# Received frequency : 66.0
# Received frequency : 65.0
# Received frequency : 64.0
# Received frequency : 62.0
# Received frequency : 60.0
# Received frequency : 57.0
# Received frequency : 56.0
# Received frequency : 55.0
# Received frequency : 54.0
# Received frequency : 53.0
# Received frequency : 52.0
# Received frequency : 51.0
# Received frequency : 50.0
# Received frequency : 49.0
# Received frequency : 50.0
# Received frequency : 51.0
# Received frequency : 52.0
# Received frequency : 53.0
# Received frequency : 54.0
# Received frequency : 55.0
# Received frequency : 56.0
# Received frequency : 57.0
# Received frequency : 58.0
# Received frequency : 59.0
# Received frequency : 61.0
# Received frequency : 62.0
# Received frequency : 67.0
# Received frequency : 69.0
# Received frequency : 70.0
# Received frequency : 71.0
# Received frequency : 72.0
# Received frequency : 74.0
# Received frequency : 75.0
# Received frequency : 76.0
# Received frequency : 79.0
# Received frequency : 80.0
# Received frequency : 82.0
# Received frequency : 83.0
# Received frequency : 85.0
# Received frequency : 86.0
# Received frequency : 87.0
# Received frequency : 88.0
# Received frequency : 89.0
# Received frequency : 90.0
# Received frequency : 91.0
# Received frequency : 92.0
# Received frequency : 91.0
# Received frequency : 90.0
# Received frequency : 87.0
# Received frequency : 84.0
# Received frequency : 83.0
# Received frequency : 82.0
# Received frequency : 81.0
# Received frequency : 80.0
# Received frequency : 79.0
# Received frequency : 78.0
# Received frequency : 77.0
# Received frequency : 76.0
# Received frequency : 75.0
# Received frequency : 74.0
# Received frequency : 73.0
# Received frequency : 72.0
# Received frequency : 71.0
# Received frequency : 70.0
# Received frequency : 69.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[61], line 2
#       1 server = OSCServer(1223, 1224)
# ----> 2 server.start_server()
#
# Cell In[59], line 31, in OSCServer.start_server(self)
#      29 def start_server(self):
#      30     # Launch the server
# ---> 31     self.server.serve_forever()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/socketserver.py:232, in BaseServer.serve_forever(self, poll_interval)
#     229 selector.register(self, selectors.EVENT_READ)
#     231 while not self.__shutdown_request:
# --> 232     ready = selector.select(poll_interval)
#     233     # bpo-35017: shutdown() called during select(), exit immediately.
#     234     if self.__shutdown_request:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %%
from pythonosc import osc_server
from pythonosc import dispatcher
from pythonosc import udp_client
import math
import librosa as li
import tensorflow as tf
import io
import csv
import numpy as np
import tensorflow_hub as hub

# OSC decorator
def osc_parse(func):
    '''decorates a python function to automatically transform args and kwargs coming from Max'''
    def func_embedding(address, *args):
        t_args = tuple(); kwargs = {}
        for a in args:
            if issubclass(type(a), str):
                if "=" in a:
                    key, value = a.split("=")
                    kwargs[key] = value
                else:
                    t_args = t_args + (a,)
            else:
                t_args = t_args + (a,)
        return func(*t_args, **kwargs)
    return func_embedding

# Find the name of the class with the top score when mean-aggregated across frames.
def class_names_from_csv(class_map_csv_text):
    """Returns list of class names corresponding to score vector."""
    class_map_csv = io.StringIO(class_map_csv_text)
    class_names = [display_name for (class_index, mid, display_name) in csv.reader(class_map_csv)]
    class_names = class_names[1:]  # Skip CSV header
    return class_names
    
class OSCServer():

    def __init__(self, in_port, out_port, ip="127.0.0.1", *args):
        self.ip = ip
        self.port_in = in_port
        self.port_out = out_port
        # Client object to use in functions
        self.client = udp_client.SimpleUDPClient(self.ip, self.port_out)
        # Create a dispatcher
        self.dispatch = dispatcher.Dispatcher()
        # Initialize all bindings
        self.init_bindings()
        # Create the server
        self.server = osc_server.BlockingOSCUDPServer((ip, self.port_in), self.dispatch)
        # Add the model
        self.model = hub.load('https://tfhub.dev/google/yamnet/1')
        # Create class names associations
        class_map_path = self.model.class_map_path().numpy()
        # Final class names vector
        self.class_names = class_names_from_csv(tf.io.read_file(class_map_path).numpy().decode('utf-8'))
        print('Finished creation')

    def init_bindings(self):
        # Mapping message to the function
        self.dispatch.map("/synth/frequency", self.synth_frequency)
        self.dispatch.map("/classify", osc_parse(self.classify))
        self.dispatch.map("/stop", self.stop_server)

    # Function to react to an incoming /synth/frequency message
    def synth_frequency(self, address, fundamental_freq, nb_freq):
        print('yuss')
        # Create a list of frequencies
        golden_freqs = []
        # Define the golden ratio
        golden_ratio = (1 + math.sqrt(5)) / 2
        # create a series based on the golden ratio
        for i in range(int(nb_freq)):
            # set the frequency of the oscillator to be a multiple of the fundamental following a progression based on the golden ratio
            golden_freqs.append(fundamental_freq * (golden_ratio ** i))
        # Send back the frequency
        self.client.send_message("/synth/frequency", golden_freqs)

    def classify(self, file_path):
        print("Received")
        print(file_path)
        file_path = file_path.split(':')[-1]
        y, sr = li.load(file_path)
        y_resample = li.resample(y, orig_sr=sr, target_sr=16000)
        scores, embedding, spectro = self.model(y_resample)
        final_class = self.class_names[scores.numpy().mean(axis=0).argmax()]
        # Send back the frequency
        self.client.send_message("/classify", final_class)

    def start_server(self):
        # Launch the server
        self.server.serve_forever()

    def stop_server(self, *args):
        self.client.send_message("/terminated", "bang")
        self.server.shutdown()
        self.server.socket.close()

# %%
server = OSCServer(1230, 1231)
server.start_server()
# Out:
# Finished creation
# Received
# Macintosh HD:/Users/esling/Downloads/shaite.wav
# Received
# Macintosh HD:/Users/esling/Sound/philex_soundset/bass/loop_bass_01_wobl_hard.wav
# Received
# Macintosh HD:/Users/esling/Sound/philex_soundset/bass/top_loop_noise_05.wav
# Received
# Macintosh HD:/Users/esling/Sound/philex_soundset/fx/atmo_04_bells.wav
# Received
# Macintosh HD:/Users/esling/Sound/philex_soundset/snares/clap_01.wav
# Received
# Macintosh HD:/Users/esling/Sound/philex_soundset/scrape/scrape_02.wav
# Received
# Macintosh HD:/Users/esling/Sound/philex_soundset/percs/bongo_03.wav
# Received
# Macintosh HD:/Users/esling/Sound/philex_soundset/percs/fill_02.wav
# Received
# Macintosh HD:/Users/esling/Sound/philex_soundset/hats/closed_04.wav
# Received
# Macintosh HD:/Users/esling/Sound/philex_soundset/bass/loop_bass_03_wobl_filt.wav
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/cats_clean/Cat_65.wav
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/cats_clean/Animal_30.wav
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/drums/Clap/VEE Clap 050.wav
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/drums/Clap/VEH3 Claps 106.wav
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/drums/Clap/VEE Clap 080.wav
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/drums/Cymbal/VEE2 Crash 39.wav
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/drums/Cymbal/VEC3 Cymbals Crash 10.wav
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/vocal_imitations/raw/Machine03.wav
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/vocal_imitations/raw/Abstract06.wav
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/synth_testing/E_Lead_C4.aif
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/sol-ordinario/audio/Brass_Trumpet-C-77-mf-ordinario_0.wav
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/sol-ordinario/audio/Strings_Violoncello-58-ff-ordinario_0.wav
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/sol-ordinario/audio/Keyboards_Piano-48-mf-ordinario_0.wav
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/voices/Rose (Urgent)-die_.wav
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/voices/General Herring-die_.wav
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/cats_clean/Cat_65.wav
# Received
# Macintosh HD:/Users/esling/Datasets/waveform/voices/shaite.wav
